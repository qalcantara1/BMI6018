# %% [markdown]
# # Attributes and class keywords

# %%
class NameOfClass():
    def __init__(self, param1, param2): #Not a function! I am a method when I am inside the class
        self.param1 = param1
        self.param2 = param2
    
    def some_method(self):
        #perform some action
        print(self.param1)

# %%
mylist = [1,2,3]

# %%
mylist.
# Out:
# list

# %%
class SampleWord(): #camel casing AaaGggAaaIiiNnn! 
    pass #doesn't do anything!

# %%
my_sample = SampleWord()
type(my_sample)
# Out:
# __main__.SampleWord

# %%
class Dog():
    def __init__(self,breed):
        self.breed = breed

# %%
my_dog = Dog(breed = 'Lab')

# %%
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.breed
# Out:
# 'Lab'

# %%
class Dog():
    def __init__(self,mybreed):
        self.my_attribute = mybreed

# %%
my_dog = Dog(mybreed = 'Huskie')

# %%
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.my_attribute
# Out:
# 'Huskie'

# %%
class Dog():
    
    species = 'mammal'
    def __init__(self,breed, name, spots):
        self.breed = breed
        self.name= name
        self.spots = spots
        
    def bark(self): 
        print("WOOF! My name is {}".format(self.name))

# %%
my_dog = Dog(breed = 'Huskie', name = 'Sam', spots ="No")

# %%
my_dog.breed
# Out:
# 'Huskie'

# %%
my_dog.name
# Out:
# 'Sam'

# %%
my_dog.spots
# Out:
# 'No'

# %%
my_dog.species
# Out:
# 'mammal'

# %%
my_dog.bark()
# Out:
# WOOF! My name is Sam

# %%
class Circle():
    pi = 3.14
    def __init__(self,radius = 1):
        self.radius = radius
    
    def get_circumference(self):
        return self.radius * self.pi * 2

# %%
my_circle = Circle()

# %%
my_circle.radius
# Out:
# 1

# %%
my_circle.pi
# Out:
# 3.14

# %%
my_circle = Circle(20)

# %%
my_circle.radius
# Out:
# 20

# %%
my_circle.get_circumference()
# Out:
# 125.60000000000001

# %% [markdown]
# # Inheritance

# %%
class Animal():
    def __init__(self):
        print("ANIMAL")
    def who_am_I(self):
        print("I am an Animal")
    def eat(self):
        print("I am eating")

# %%
myanimal = Animal()
# Out:
# ANIMAL

# %%
myanimal.eat()
# Out:
# I am eating

# %%
myanimal.who_am_I()
# Out:
# I am an Animal

# %%
class Dog(Animal):
    def __init__(self):
        Animal.__init__(self)
        print("Dog Created")
        
    def eat(self):
        print("I am eating my food and barking")
    
    def bark(self):
        print("Woof I am a Dog")

# %%
mydog=Dog()
# Out:
# ANIMAL
# Dog Created

# %%
mydog.eat()
# Out:
# I am eating my food and barking

# %%
mydog.who_am_I()
# Out:
# I am an Animal

# %% [markdown]
# # Polymorphism

# %%
class Dog():
    def __init__(self,name):
        self.name = name
    def speak(self):
        return self.name + " say Woof!"

# %%
class Cat():
    def __init__(self,name):
        self.name = name
    def speak(self):
        return self.name + " say Meow!"

# %%
rob = Dog("Rob")
fluffy = Cat("Fluffy")

# %%
print(rob.speak())
# Out:
# Rob say Woof!

# %%
print(fluffy.speak())
# Out:
# Fluffy say Meow!

# %%
for pet in [rob, fluffy]:
    print(type(pet))
    print(pet.speak())
# Out:
# <class '__main__.Dog'>
# Rob say Woof!
# <class '__main__.Cat'>
# Fluffy say Meow!

# %%
def pet_speak(pet):
    print(pet.speak())

# %%
pet_speak(rob)
# Out:
# Rob say Woof!

# %%
pet_speak(fluffy)
# Out:
# Fluffy say Meow!

# %%
class Animal():
    def __init__(self, name):
        self.name = name
    
    def speak(self):
        raise ImplementationError("We must implementing this abstract method")

# %%
freed = Animal('Freed')

# %%
freed.speak()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11680/634278093.py in <module>
# ----> 1 freed.speak()
#
# ~\AppData\Local\Temp/ipykernel_11680/263635041.py in speak(self)
#       4
#       5     def speak(self):
# ----> 6         raise ImplementationError("We must implementing this abstract method")
#
# NameError: name 'ImplementationError' is not defined

# %%
class Dog(Animal):
    def speak(self):
        return self.name +" Says Woof!"

# %%
fido = Dog("Fido")

# %%
fido.speak()
# Out:
# 'Fido Says Woof!'

# %% [markdown]
# # Special Method

# %%
mylist = [1,2,3]

# %%
len(mylist)
# Out:
# 3

# %%
class Sample():
    pass

# %%
mysample = Sample()

# %%
len(mysample)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11680/3077576814.py in <module>
# ----> 1 len(mysample)
#
# TypeError: object of type 'Sample' has no len()

# %%
print(mysample)
# Out:
# <__main__.Sample object at 0x00000229453CF2B0>

# %%
print(mylist)
# Out:
# [1, 2, 3]

# %%
class Book():
    def __init__(self,title,author,pages):
        self.title = title
        self.author = author 
        self.pages = pages
    
    def __str__ (self):
        return f"{self.title} by {self.author}"
    
    def __len__ (self):
        return self.pages
    
    def __del__ (self):
        print ("A book has been deleted")

# %%
b = Book('Python', 'Ram', 200)

# %%
print(b)
# Out:
# Python by Ram

# %%
str(b)
# Out:
# 'Python by Ram'

# %%
len(b)
# Out:
# 200

# %%
del b
# Out:
# A book has been deleted

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11680/1685013873.py in <module>
# ----> 1 b
#
# NameError: name 'b' is not defined
